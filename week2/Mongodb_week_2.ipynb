# %%
#javascript code to create the studet

use school
db.scores.drop();
var types = ['exam', 'homework', 'quiz']
for (student_id = 0; student_id < 100; student_id++) {
    for (type=0; type < 3; type++) {
	var r = {'student_id':student_id, 'type':types[type], 'score':Math.random() * 100};
	db.scores.insert(r);
    }
}

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the school database
db=connection.school
scores = db.scores


def find():

    print "find, reporting for duty"

    query = {'type':'exam'}

    try:
        cursor = scores.find(query)

    except Exception as e:
        print "Unexpected error:", type(e), e

    sanity = 0
    
    for doc in cursor:
        print doc.values()
        sanity += 1
        if (sanity > 10):
            break
        


def find_one():

    print "find one, reporting for duty"
    query = {'student_id':10}
    
    try:
        doc = scores.find_one(query)
        
    except Exception as e:
        print "Unexpected error:", type(e), e

    
    print doc

# %%
find()
# Out:
# find, reporting for duty
# [0.0, ObjectId('55ccc622376e38829de6dbba'), u'exam', 58.37300564162433]
# [1.0, ObjectId('55ccc622376e38829de6dbbd'), u'exam', 7.3194925440475345]
# [2.0, ObjectId('55ccc622376e38829de6dbc0'), u'exam', 74.13568322081119]
# [3.0, ObjectId('55ccc622376e38829de6dbc3'), u'exam', 81.68885167688131]
# [4.0, ObjectId('55ccc622376e38829de6dbc6'), u'exam', 18.71509898919612]
# [5.0, ObjectId('55ccc622376e38829de6dbc9'), u'exam', 68.73156470246613]
# [6.0, ObjectId('55ccc622376e38829de6dbcc'), u'exam', 21.910550934262574]
# [7.0, ObjectId('55ccc622376e38829de6dbcf'), u'exam', 49.77000814396888]
# [8.0, ObjectId('55ccc622376e38829de6dbd2'), u'exam', 85.77402182854712]
# [9.0, ObjectId('55ccc622376e38829de6dbd5'), u'exam', 78.89861278235912]
# [10.0, ObjectId('55ccc622376e38829de6dbd8'), u'exam', 57.132212817668915]

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the school database
db=connection.school
scores = db.scores


def find():

    print "find, reporting for duty"

    query = {'type':'exam'}
    projection = {'student_id':1, '_id':0}
    #projection = {'student_id':1}

    try:
        cursor = scores.find(query, projection)

    except Exception as e:
        print "Unexpected error:", type(e), e

    sanity = 0
    for doc in cursor:
        print doc
        sanity += 1
        if (sanity > 10):
            break
        



find()
# Out:
# find, reporting for duty
# {u'student_id': 0.0}
# {u'student_id': 1.0}
# {u'student_id': 2.0}
# {u'student_id': 3.0}
# {u'student_id': 4.0}
# {u'student_id': 5.0}
# {u'student_id': 6.0}
# {u'student_id': 7.0}
# {u'student_id': 8.0}
# {u'student_id': 9.0}
# {u'student_id': 10.0}

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the school database
db=connection.students
scores = db.grades


def find():

    print "find, reporting for duty"

    query = {'type':'exam', 'score':{'$gt':50, '$lt':70}}
    queryhw = {'type':'exam', 'score':{'$gte':65}}
    projection = {'student_id':1, 'type':1, '_id':0, 'score':1}
    
    cursor = scores.find(queryhw)
    #cursor = cursor.limit(10)

    #cursor = cursor.sort('student_id', pymongo.ASCENDING).skip(4).limit(1)

    cursor = cursor.sort([('student_id',pymongo.ASCENDING),
                          ('score',pymongo.DESCENDING)])

    '''try:
        cursor = scores.find(queryhw, projection)

    except Exception as e:
        print "Unexpected error:", type(e), e'''

    sanity = 0
    for doc in cursor:
        print doc
        '''sanity += 1
        if (sanity > 10):
            break'''
        

find()
# Out:
# find, reporting for duty
# {u'student_id': 1, u'_id': ObjectId('50906d7fa3c412bb040eb57b'), u'type': u'exam', u'score': 74.20010837299897}
# {u'student_id': 3, u'_id': ObjectId('50906d7fa3c412bb040eb583'), u'type': u'exam', u'score': 92.6244233936537}
# {u'student_id': 4, u'_id': ObjectId('50906d7fa3c412bb040eb587'), u'type': u'exam', u'score': 87.89071881934647}
# {u'student_id': 6, u'_id': ObjectId('50906d7fa3c412bb040eb58f'), u'type': u'exam', u'score': 97.56302189646776}
# {u'student_id': 8, u'_id': ObjectId('50906d7fa3c412bb040eb597'), u'type': u'exam', u'score': 76.78123286903039}
# {u'student_id': 13, u'_id': ObjectId('50906d7fa3c412bb040eb5ab'), u'type': u'exam', u'score': 80.28230979707159}
# {u'student_id': 14, u'_id': ObjectId('50906d7fa3c412bb040eb5af'), u'type': u'exam', u'score': 93.38696333100664}
# {u'student_id': 18, u'_id': ObjectId('50906d7fa3c412bb040eb5bf'), u'type': u'exam', u'score': 91.08706438561104}
# {u'student_id': 21, u'_id': ObjectId('50906d7fa3c412bb040eb5cb'), u'type': u'exam', u'score': 75.29800347780863}
# {u'student_id': 22, u'_id': ObjectId('50906d7fa3c412bb040eb5cf'), u'type': u'exam', u'score': 65.02518811936324}
# {u'student_id': 25, u'_id': ObjectId('50906d7fa3c412bb040eb5db'), u'type': u'exam', u'score': 93.3969528159085}
# {u'student_id': 26, u'_id': ObjectId('50906d7fa3c412bb040eb5df'), u'type': u'exam', u'score': 92.67702875321054}
# {u'student_id': 33, u'_id': ObjectId('50906d7fa3c412bb040eb5fb'), u'type': u'exam', u'score': 97.72432789308246}
# {u'student_id': 34, u'_id': ObjectId('50906d7fa3c412bb040eb5ff'), u'type': u'exam', u'score': 78.98904466549635}
# {u'student_id': 35, u'_id': ObjectId('50906d7fa3c412bb040eb603'), u'type': u'exam', u'score': 80.64873235230371}
# {u'student_id': 41, u'_id': ObjectId('50906d7fa3c412bb040eb61b'), u'type': u'exam', u'score': 80.33393381385598}
# {u'student_id': 42, u'_id': ObjectId('50906d7fa3c412bb040eb61f'), u'type': u'exam', u'score': 93.0847136081113}
# {u'student_id': 44, u'_id': ObjectId('50906d7fa3c412bb040eb627'), u'type': u'exam', u'score': 87.89675218010804}
# {u'student_id': 45, u'_id': ObjectId('50906d7fa3c412bb040eb62b'), u'type': u'exam', u'score': 75.37160689441282}
# {u'student_id': 47, u'_id': ObjectId('50906d7fa3c412bb040eb633'), u'type': u'exam', u'score': 95.5716490266884}
# {u'student_id': 48, u'_id': ObjectId('50906d7fa3c412bb040eb637'), u'type': u'exam', u'score': 65.71867938396781}
# {u'student_id': 50, u'_id': ObjectId('50906d7fa3c412bb040eb63f'), u'type': u'exam', u'score': 76.78657290704423}
# {u'student_id': 51, u'_id': ObjectId('50906d7fa3c412bb040eb643'), u'type': u'exam', u'score': 75.86543700819128}
# {u'student_id': 52, u'_id': ObjectId('50906d7fa3c412bb040eb647'), u'type': u'exam', u'score': 98.11044728841873}
# {u'student_id': 53, u'_id': ObjectId('50906d7fa3c412bb040eb64b'), u'type': u'exam', u'score': 77.0986666152772}
# {u'student_id': 54, u'_id': ObjectId('50906d7fa3c412bb040eb64f'), u'type': u'exam', u'score': 92.66352609379979}
# {u'student_id': 56, u'_id': ObjectId('50906d7fa3c412bb040eb657'), u'type': u'exam', u'score': 76.26143783619797}
# {u'student_id': 57, u'_id': ObjectId('50906d7fa3c412bb040eb65b'), u'type': u'exam', u'score': 65.91867871499709}
# {u'student_id': 64, u'_id': ObjectId('50906d7fa3c412bb040eb677'), u'type': u'exam', u'score': 71.07663195175958}
# {u'student_id': 67, u'_id': ObjectId('50906d7fa3c412bb040eb683'), u'type': u'exam', u'score': 67.64289324359295}
# {u'student_id': 70, u'_id': ObjectId('50906d7fa3c412bb040eb68f'), u'type': u'exam', u'score': 90.75101320399959}
# {u'student_id': 81, u'_id': ObjectId('50906d7fa3c412bb040eb6bb'), u'type': u'exam', u'score': 80.54749065546406}
# {u'student_id': 82, u'_id': ObjectId('50906d7fa3c412bb040eb6bf'), u'type': u'exam', u'score': 75.74280721971942}
# {u'student_id': 83, u'_id': ObjectId('50906d7fa3c412bb040eb6c3'), u'type': u'exam', u'score': 79.5815891235159}
# {u'student_id': 85, u'_id': ObjectId('50906d7fa3c412bb040eb6cb'), u'type': u'exam', u'score': 80.79076184869429}
# {u'student_id': 86, u'_id': ObjectId('50906d7fa3c412bb040eb6cf'), u'type': u'exam', u'score': 78.91805515303193}
# {u'student_id': 87, u'_id': ObjectId('50906d7fa3c412bb040eb6d3'), u'type': u'exam', u'score': 66.0470217410135}
# {u'student_id': 96, u'_id': ObjectId('50906d7fa3c412bb040eb6f7'), u'type': u'exam', u'score': 67.39154510277987}
# {u'student_id': 99, u'_id': ObjectId('50906d7fa3c412bb040eb703'), u'type': u'exam', u'score': 96.70764264778711}
# {u'student_id': 102, u'_id': ObjectId('50906d7fa3c412bb040eb70f'), u'type': u'exam', u'score': 89.05971931430759}
# {u'student_id': 104, u'_id': ObjectId('50906d7fa3c412bb040eb717'), u'type': u'exam', u'score': 72.42031903025907}
# {u'student_id': 108, u'_id': ObjectId('50906d7fa3c412bb040eb727'), u'type': u'exam', u'score': 77.43246779106391}
# {u'student_id': 109, u'_id': ObjectId('50906d7fa3c412bb040eb72b'), u'type': u'exam', u'score': 74.26032936907711}
# {u'student_id': 111, u'_id': ObjectId('50906d7fa3c412bb040eb733'), u'type': u'exam', u'score': 67.16752597563053}
# {u'student_id': 115, u'_id': ObjectId('50906d7fa3c412bb040eb743'), u'type': u'exam', u'score': 65.47329199925679}
# {u'student_id': 116, u'_id': ObjectId('50906d7fa3c412bb040eb747'), u'type': u'exam', u'score': 67.09938431313856}
# {u'student_id': 119, u'_id': ObjectId('50906d7fa3c412bb040eb753'), u'type': u'exam', u'score': 94.73800681014144}
# {u'student_id': 120, u'_id': ObjectId('50906d7fa3c412bb040eb757'), u'type': u'exam', u'score': 68.695274154639}
# {u'student_id': 122, u'_id': ObjectId('50906d7fa3c412bb040eb75f'), u'type': u'exam', u'score': 84.17466551666908}
# {u'student_id': 124, u'_id': ObjectId('50906d7fa3c412bb040eb767'), u'type': u'exam', u'score': 76.14987462033146}
# {u'student_id': 130, u'_id': ObjectId('50906d7fa3c412bb040eb77f'), u'type': u'exam', u'score': 88.47324072914611}
# {u'student_id': 131, u'_id': ObjectId('50906d7fa3c412bb040eb783'), u'type': u'exam', u'score': 93.75626671479587}
# {u'student_id': 139, u'_id': ObjectId('50906d7fa3c412bb040eb7a3'), u'type': u'exam', u'score': 90.49031467167573}
# {u'student_id': 140, u'_id': ObjectId('50906d7fa3c412bb040eb7a7'), u'type': u'exam', u'score': 75.0747972797953}
# {u'student_id': 145, u'_id': ObjectId('50906d7fa3c412bb040eb7bb'), u'type': u'exam', u'score': 84.95291702163877}
# {u'student_id': 146, u'_id': ObjectId('50906d7fa3c412bb040eb7bf'), u'type': u'exam', u'score': 92.66434665285378}
# {u'student_id': 149, u'_id': ObjectId('50906d7fa3c412bb040eb7cb'), u'type': u'exam', u'score': 85.39263494631119}
# {u'student_id': 156, u'_id': ObjectId('50906d7fa3c412bb040eb7e7'), u'type': u'exam', u'score': 96.22686187212408}
# {u'student_id': 158, u'_id': ObjectId('50906d7fa3c412bb040eb7ef'), u'type': u'exam', u'score': 93.19296494559896}
# {u'student_id': 160, u'_id': ObjectId('50906d7fa3c412bb040eb7f7'), u'type': u'exam', u'score': 94.16339119517072}
# {u'student_id': 163, u'_id': ObjectId('50906d7fa3c412bb040eb803'), u'type': u'exam', u'score': 67.51445811302555}
# {u'student_id': 164, u'_id': ObjectId('50906d7fa3c412bb040eb807'), u'type': u'exam', u'score': 87.59468512168375}
# {u'student_id': 166, u'_id': ObjectId('50906d7fa3c412bb040eb80f'), u'type': u'exam', u'score': 68.42859593432789}
# {u'student_id': 168, u'_id': ObjectId('50906d7fa3c412bb040eb817'), u'type': u'exam', u'score': 80.38541560762634}
# {u'student_id': 176, u'_id': ObjectId('50906d7fa3c412bb040eb837'), u'type': u'exam', u'score': 99.96723280505422}
# {u'student_id': 177, u'_id': ObjectId('50906d7fa3c412bb040eb83b'), u'type': u'exam', u'score': 96.50174787571963}
# {u'student_id': 180, u'_id': ObjectId('50906d7fa3c412bb040eb847'), u'type': u'exam', u'score': 72.82141551673207}
# {u'student_id': 181, u'_id': ObjectId('50906d7fa3c412bb040eb84b'), u'type': u'exam', u'score': 89.10554845143109}
# {u'student_id': 183, u'_id': ObjectId('50906d7fa3c412bb040eb853'), u'type': u'exam', u'score': 78.02079965581102}
# {u'student_id': 184, u'_id': ObjectId('50906d7fa3c412bb040eb857'), u'type': u'exam', u'score': 74.07556531186303}
# {u'student_id': 187, u'_id': ObjectId('50906d7fa3c412bb040eb863'), u'type': u'exam', u'score': 92.46011468967426}
# {u'student_id': 189, u'_id': ObjectId('50906d7fa3c412bb040eb86b'), u'type': u'exam', u'score': 71.2461033044598}
# {u'student_id': 190, u'_id': ObjectId('50906d7fa3c412bb040eb86f'), u'type': u'exam', u'score': 72.80738441829857}
# {u'student_id': 194, u'_id': ObjectId('50906d7fa3c412bb040eb87f'), u'type': u'exam', u'score': 67.09136149008972}
# {u'student_id': 197, u'_id': ObjectId('50906d7fa3c412bb040eb88b'), u'type': u'exam', u'score': 95.96860886271084}
# {u'student_id': 199, u'_id': ObjectId('50906d7fa3c412bb040eb893'), u'type': u'exam', u'score': 67.33828604577803}

# %%
#Asi esta bien
import json
import urllib2
import pymongo

# connect to mongo
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the reddit database
db=connection.reddit
stories = db.stories

# drop existing collection
stories.drop()

# get the reddit home page
reddit = r'C:\Users\Diego\Desktop\Cursos\MongoDB\week2\reddit.json'

# parse the json into python objects
with open(reddit) as data_file:    
    data = json.load(data_file)

# iterate through every news item on the page
for item in data['data']['children']:
    # put it in mongo
    stories.insert(item['data'])

# %%
reddit
# Out:
# 'C:\\Users\\Diego\\Desktop\\Cursos\\MongoDB\\week2\\reddit.json'

# %%
import json
from pprint import pprint

with open(reddit) as data_file:    
    data = json.load(data_file)

for item in data['data']['children']:
    pprint(item['data'])
# Out:
#   File "<ipython-input-23-209ff3bb2915>", line 8
#     pprint(item['data']).
#                          ^
# SyntaxError: invalid syntax

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the school database
db=connection.reddit
stories = db.stories


def find():

    print "find, reporting for duty"

    query = {'title':{'$regex':'apple|google|Microsoft', '$options':'i'}}
    projection = {'title':1, '_id':0}

    try:
        cursor = stories.find(query, projection)

    except Exception as e:
        print "Unexpected error:", type(e), e

    for doc in cursor:
        print doc

        

find()
# Out:
# find, reporting for duty
# {u'title': u'Microsoft ships IE10, Mozilla congratulates with a cake'}
# {u'title': u'Why I\u2019m Returning My Microsoft Surface RT'}
# {u'title': u'\nSurprise! There\u2019s Apple-Like Lines For Microsoft\u2019s New Tablet'}
# {u'title': u"Google's Android event canceled due to hurricane"}
# {u'title': u'At the moment, Microsoft Surface is hot '}
# {u'title': u'Install Google Search and Chrome in Windows 8 - By Google'}
# {u'title': u"Gentlefolk of Reddit, you will love this: Futurist Gerd Leonhard discusses the future of media (criticises Apple, SOPA etc., Music, film and Oil industry for trying to hold onto the 'egosystems' of the past). Essential viewing for anyone with an interest in media.  Seriously wonderful stuff"}

# %%
#homework 2.1

import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# get a handle to the school database
db=connection.students
scores = db.grades


def find():

    print "find, reporting for duty"

    queryhw = {'type':'exam', 'score':{'$gte':65}}

    try:

        cursor = scores.find(queryhw)
        cursor = cursor.limit(10)

        #cursor = cursor.sort('student_id', pymongo.ASCENDING).skip(4).limit(1)
        
        cursor = cursor.sort([('score',pymongo.ASCENDING)])



    except Exception as e:
        print "Unexpected error:", type(e), e

    for doc in cursor:
        print doc
        


def find_one():

    print "find one, reporting for duty"
    query = {'student_id':10}
    
    try:
        doc = scores.find_one(query)
        
    except Exception as e:
        print "Unexpected error:", type(e), e

    
    print doc


find()
# Out:
# find, reporting for duty
# {u'student_id': 22, u'_id': ObjectId('50906d7fa3c412bb040eb5cf'), u'type': u'exam', u'score': 65.02518811936324}
# {u'student_id': 115, u'_id': ObjectId('50906d7fa3c412bb040eb743'), u'type': u'exam', u'score': 65.47329199925679}
# {u'student_id': 48, u'_id': ObjectId('50906d7fa3c412bb040eb637'), u'type': u'exam', u'score': 65.71867938396781}
# {u'student_id': 57, u'_id': ObjectId('50906d7fa3c412bb040eb65b'), u'type': u'exam', u'score': 65.91867871499709}
# {u'student_id': 87, u'_id': ObjectId('50906d7fa3c412bb040eb6d3'), u'type': u'exam', u'score': 66.0470217410135}
# {u'student_id': 194, u'_id': ObjectId('50906d7fa3c412bb040eb87f'), u'type': u'exam', u'score': 67.09136149008972}
# {u'student_id': 116, u'_id': ObjectId('50906d7fa3c412bb040eb747'), u'type': u'exam', u'score': 67.09938431313856}
# {u'student_id': 111, u'_id': ObjectId('50906d7fa3c412bb040eb733'), u'type': u'exam', u'score': 67.16752597563053}
# {u'student_id': 199, u'_id': ObjectId('50906d7fa3c412bb040eb893'), u'type': u'exam', u'score': 67.33828604577803}
# {u'student_id': 96, u'_id': ObjectId('50906d7fa3c412bb040eb6f7'), u'type': u'exam', u'score': 67.39154510277987}

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")


def insert():

    # get a handle to the school database
    db=connection.school
    people = db.people
    
    people.drop()

    print "insert, reporting for duty"

    richard ={"name":"Richard Kreuter", "company":"MongoDB",
              "interests":['horses', 'skydiving', 'fencing']}    
    andrew = {"_id":"erlichson", "name":"Andrew Erlichson", "company":"MongoDB",
              "interests":['running', 'cycling', 'photography']}

    ls = [richard, andrew]
    try:
        #for i in ls: NO HACE FALTA EL BUCLE XA INSERTAR LOS VALORES
        people.insert(ls)
        #people.insert(richard)
        #people.insert(andrew)

    except Exception as e:
        print "Unexpected error:", type(e), e

    #print(richard)
    #print(andrew)




insert()
# Out:
# insert, reporting for duty

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")


def insert_many():

    # get a handle to the school database
    db=connection.school
    people = db.people
    people.drop()

    print "insert_many, reporting for duty"

    andrew = {"_id":"erlichson", "name":"Andrew Erlichson", "company":"MongoDB",
              "interests":['running', 'cycling', 'photography']}

    richard ={"name":"Richard Kreuter", "company":"MongoDB",
              "interests":['horses', 'skydiving', 'fencing']}    

    people_to_insert = [andrew,richard]


    try:
        people.insert(people_to_insert,ordered=True)

    except Exception as e:
        print "Unexpected error:", type(e), e

def print_people():
    # get a handle to the school database
    db=connection.school
    people = db.people

    cur = people.find({},{'name':1})
    for doc in cur:
        print doc

print "Before the insert_many, here are the people"
print_people()
insert_many()
print "\n\nAfter the insert_many, here are the people"
print_people()
# Out:
# Before the insert_many, here are the people
# insert_many, reporting for duty
# Unexpected error: <type 'exceptions.TypeError'> __init__() got an unexpected keyword argument 'ordered'
#
#
# After the insert_many, here are the people

# %%
import pymongo
import time, datetime
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")
        
# add a review date to a single record using update_one
def add_review_date_using_update_one(student_id):

    print "updating record using update_one and $set"
    # get a handle to the school database
    db=connection.school
    scores = db.scores

    try:
        # get the doc
        score = scores.find_one({'student_id':student_id, 'type':'homework'})
        print "before: ", score

        # update using set
        record_id = score['_id']
        result = scores.update_one({'_id':record_id},
                          {'$set':{'review_date':datetime.datetime.utcnow()}})
        print "num matched: ", result.matched_count

        score = scores.find_one({'_id':record_id})
        print "after: ", score

    except Exception as e:
        raise


# add a review date to all records
def add_review_dates_for_all():

    print "updating record using update_one and $set"
    # get a handle to the school database
    db=connection.school
    scores = db.scores

    try:
        # update all the docs
        result = score = scores.update_many({},{'$set':{'review_date':time.ctime()}})
        print "num matched: ", result.matched_count

    except Exception as e:
        raise


#add_review_date_using_update_one(1)
add_review_dates_for_all()
# Out:
# updating record using update_one and $set
# num matched:  300

# %%
time.ctime()
# Out:
# 'Fri Aug 14 13:03:50 2015'

# %%
datetime.datetime.utcnow()
# Out:
# datetime.datetime(2015, 8, 14, 11, 4, 36, 377000)

# %%
import pymongo
import datetime
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")

# removes all review dates
def remove_all_review_dates():
    print "\n\nremoving all review dates"

    # get a handle to the school database
    db=connection.school
    scores = db.scores
    try:
        result = scores.update_many({'review_date':{'$exists':True}},
                                    {'$unset':{'review_date':1}})
        print "Matched this number of docs: ", result.matched_count

    except Exception as e:
        print "Unexpected error:", type(e), e
        raise


        

# add a review date to single record using replace_one
def add_review_date_using_replace_one(student_id):

    # get a handle to the school database
    db=connection.school
    scores = db.scores

    print "updating record using replace_one"

    try:
        # get the doc
        score = scores.find_one({'student_id':student_id, 'type':'homework'})
        print "before: ", score

        # add a review_date
        score['review_date'] = time.ctime()

        # update the record with replace_one
        record_id = score['_id']
        scores.replace_one({'_id': record_id}, score)
        score = scores.find_one({'_id': record_id})
        print "after: ", score

    except Exception as e:
        print "Unexpected error:", type(e), e
        raise


remove_all_review_dates()
add_review_date_using_replace_one(1)
# Out:
# removing all review dates
# Matched this number of docs:  300
# updating record using replace_one
# before:  {u'student_id': 1.0, u'_id': ObjectId('55ccc622376e38829de6dbbe'), u'type': u'homework', u'score': 96.61970203742385}
# after:  {u'student_id': 1.0, u'_id': ObjectId('55ccc622376e38829de6dbbe'), u'type': u'homework', u'score': 96.61970203742385, u'review_date': u'Fri Aug 14 13:40:11 2015'}

# %%
import pymongo
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")
db = connection.test
things = db.things

def using_upsert():

    print "updating with upsert"

    try:

        # lets remove all stuff from things
        things.drop()

        things.update_one({'thing':'apple'}, {'$set':{'color':'red'}}, upsert=True)
	things.update_many({'thing':'banana'}, {'$set':{'color':'yellow'}}, upsert=True)
        things.replace_one({'thing':'pear'}, {'color':'green'}, upsert=True)


        apple = things.find_one({'thing':'apple'})
        print "apple: ", apple
        banana = things.find_one({'thing':'banana'})
        print "banana: ", banana 
        pear = things.find_one({'thing':'pear'})
        print "pear: ", pear

    except Exception as e:
        print "Unexpected error:", type(e), e
        raise




using_upsert()
# Out:
# updating with upsert
# apple:  {u'color': u'red', u'thing': u'apple', u'_id': ObjectId('55cdde79d98d6469146df945')}
# banana:  {u'color': u'yellow', u'thing': u'banana', u'_id': ObjectId('55cdde79d98d6469146df946')}
# pear:  None

# %%
# Andrew Erlichson
# MongoDB, Inc. 
# M101P - Copyright 2015, All Rights Reserved


import pymongo
import datetime
import sys

# establish a connection to the database
connection = pymongo.MongoClient("mongodb://localhost")
        
# removes one student
def remove_student(student_id):

    # get a handle to the school database
    db=connection.school
    scores = db.scores

    try:

        result = scores.delete_many({'student_id':student_id})

        print "num removed: ", result.deleted_count

    except Exception as e:
        print "Exception: ", type(e), e

def find_student_data(student_id):
    # get a handle to the school database
    db=connection.school
    scores = db.scores
    
    print "Searching for student data for student with id = ", student_id
    try: 
        docs = scores.find({'student_id':student_id})
        for doc in docs:
            print doc

    except Exception as e:
        print "Exception: ", type(e), e




remove_student(1)
find_student_data(1)
# Out:
# num removed:  3
# Searching for student data for student with id =  1

# %%
# Andrew Erlichson
# MongoDB, Inc. Copyright 2015 - All Rights Reserved

import pymongo

# gets the next number in a sequence
def get_next_sequence_number(name):
    connection = pymongo.MongoClient("mongodb://localhost")

    db = connection.test
    counters = db.counters

    # let's get ourselves a sequence number
    # note there are two other varients of this call as well:
    # find_one_and_delete
    # find_one_and_replace
    # all these map to the the command find_and_modify

    
    try: 
        counter = counters.find_one_and_update(filter={'type':name}, 
                                               update={'$inc':{'value':2}}, 
                                               upsert=True,
                                               return_document=pymongo.ReturnDocument.AFTER)
    except Exception as e:
        print "Exception: ", type(e), e

    counter_value = counter['value']
    return counter_value


print get_next_sequence_number('uid')
print get_next_sequence_number('uid')
print get_next_sequence_number('uid')
# Out:
# -1
# 1
# 3

# %%
import pymongo
import sys

# Homework 2.2 · Course M101P
#
# Write a program in the language of your choice that will remove the grade
# of type "homework" with the lowest score for each student from the dataset
# that you imported in HW 2.1. Since each document is one grade, it should
# remove one document per student.

connection = pymongo.MongoClient("mongodb://localhost")
db = connection.students
grades = db.grades

cursor = grades.find( { "type": "homework" }).sort( [ ("student_id", pymongo.DESCENDING), ( "score", pymongo.ASCENDING)])

ls = []

for i in cursor:
    ls.append(i)
for i in range(len(ls)-1):
    #print ls[i]
    if ls[i]['student_id'] == ls[i+1]['student_id']:
        if ls[i]['score'] < ls[i+1]['score']:
            grades.remove({ '_id': ls[i][ '_id'] } )
        else:
            grades.remove({ '_id': ls[i+1][ '_id'] } )
